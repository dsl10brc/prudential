# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import operator
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier
# %matplotlib inline 
import matplotlib.pyplot as plt
import random
#import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version a but this version of numpy is 9

# %%
train=pd.read_csv("train.csv")

# %%
train.info()
train
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.4+ MB
#           Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0          2               1             D3              10        0.076923
# 1          5               1             A1              26        0.076923
# 2          6               1             E1              26        0.076923
# 3          7               1             D4              10        0.487179
# 4          8               1             D2              26        0.230769
# 5         10               1             D2              26        0.230769
# 6         11               1             A8              10        0.166194
# 7         14               1             D2              26        0.076923
# 8         15               1             D3              26        0.230769
# ...

# %%
sum = 0
for f in train.columns:
    dfg = np.unique(list(train[f].values))
    #sum = sum +len(dfg)
    print len(dfg), f
# Out:
# 59381 Id
# 2 Product_Info_1
# 19 Product_Info_2
# 34 Product_Info_3
# 1491 Product_Info_4
# 2 Product_Info_5
# 2 Product_Info_6
# 3 Product_Info_7
# 65 Ins_Age
# 39 Ht
# 300 Wt
# 3256 BMI
# 1955 Employment_Info_1
# 36 Employment_Info_2
# 2 Employment_Info_3
# 7650 Employment_Info_4
# 2 Employment_Info_5
# 11846 Employment_Info_6
# 3 InsuredInfo_1
# 2 InsuredInfo_2
# 11 InsuredInfo_3
# 2 InsuredInfo_4
# 2 InsuredInfo_5
# 2 InsuredInfo_6
# 2 InsuredInfo_7
# 2 Insurance_History_1
# 3 Insurance_History_2
# 3 Insurance_History_3
# 3 Insurance_History_4
# 27661 Insurance_History_5
# 3 Insurance_History_7
# 3 Insurance_History_8
# 3 Insurance_History_9
# 3 Family_Hist_1
# 28724 Family_Hist_2
# 34331 Family_Hist_3
# 19252 Family_Hist_4
# 41901 Family_Hist_5
# 9060 Medical_History_1
# 579 Medical_History_2
# 3 Medical_History_3
# 2 Medical_History_4
# 3 Medical_History_5
# 3 Medical_History_6
# 3 Medical_History_7
# 3 Medical_History_8
# 3 Medical_History_9
# 58927 Medical_History_10
# ...

# %%
for i in train.columns:
    if (i != 'Id'):
        print pd.DataFrame(pd.value_counts(train[i]))
# Out:
#    Product_Info_1
# 1           57816
# 2            1565
#     Product_Info_2
# D3           14321
# D4           10812
# A8            6835
# D1            6554
# D2            6286
# E1            2647
# A1            2363
# A6            2098
# A2            1974
# A7            1383
# B2            1122
# A3             977
# A5             775
# C3             306
# C1             285
# C4             219
# A4             210
# C2             160
# B1              54
#     Product_Info_3
# 26           50892
# 10            6008
# 29            1334
# 31             411
# 15             251
# 37             139
# 30              64
# 4               58
# 8               48
# 11              40
# 28              37
# 36              25
# 9               11
# 21              11
# 23              10
# 33               9
# 2                8
# 17               3
# 6                3
# 34               2
# 3                2
# 12               2
# 32               2
# ...

# %%
for i in train.columns:
    for j in train.columns:
        if(i!=)
        x=np.corrcoef(train[i],train[j])
        print x
# Out:
# [[ 1.  1.]
#  [ 1.  1.]]
# [[ 1.         -0.00286953]
#  [-0.00286953  1.        ]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f8dd0abb7dab> in <module>()
#       1 for i in train.columns:
#       2     for j in train.columns:
# ----> 3         x=np.corrcoef(train[i],train[j])
#       4         print x
#
# /Users/shashank/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/function_base.pyc in corrcoef(x, y, rowvar, bias, ddof)
#    1949
#    1950     """
# -> 1951     c = cov(x, y, rowvar, bias, ddof)
#    1952     try:
#    1953         d = diag(c)
#
# /Users/shashank/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/numpy/lib/function_base.pyc in cov(m, y, rowvar, bias, ddof)
#    1895         X = concatenate((X, y), axis)
#    1896
# -> 1897     X -= X.mean(axis=1-axis, keepdims=True)
#    1898     if not rowvar:
# ...

# %%
# #Sample Code Kaggle

# import pandas as pd 
# import numpy as np 
# import xgboost as xgb
# from scipy.optimize import fmin_powell
# from ml_metrics import quadratic_weighted_kappa

# def eval_wrapper(yhat, y):  
#     y = np.array(y)
#     y = y.astype(int)
#     yhat = np.array(yhat)
#     yhat = np.clip(np.round(yhat), np.min(y), np.max(y)).astype(int)   
#     return quadratic_weighted_kappa(yhat, y)
    
# def get_params():
    
#     params = {}                          #dictionary
#     params["objective"] = "reg:linear"     
#     params["eta"] = 0.05
#     params["min_child_weight"] = 360
#     params["subsample"] = 0.85
#     params["colsample_bytree"] = 0.3
#     params["silent"] = 1
#     params["max_depth"] = 7
#     plst = list(params.items())

#     return plst
    
# def score_offset(data, bin_offset, sv, scorer=eval_wrapper):
#     # data has the format of pred=0, offset_pred=1, labels=2 in the first dim
#     data[1, data[0].astype(int)==sv] = data[0, data[0].astype(int)==sv] + bin_offset
#     score = scorer(data[1], data[2])
#     return score
    
# def apply_offsets(data, offsets):
#     for j in range(num_classes):
#         data[1, data[0].astype(int)==j] = data[0, data[0].astype(int)==j] + offsets[j]
#     return data

# # global variables
# columns_to_drop = ['Id', 'Response'] #, 'Medical_History_10','Medical_History_24']
# xgb_num_rounds = 720
# num_classes = 8
# missing_indicator = -1000


# print("Load the data using pandas")
# train = pd.read_csv("train.csv")
# test = pd.read_csv("test.csv")

# # combine train and test
# all_data = train.append(test)

# # Found at https://www.kaggle.com/marcellonegro/prudential-life-insurance-assessment/xgb-offset0501/run/137585/code
# # create any new variables    
# all_data['Product_Info_2_char'] = all_data.Product_Info_2.str[0]
# all_data['Product_Info_2_num'] = all_data.Product_Info_2.str[1]

# # factorize categorical variables
# all_data['Product_Info_2'] = pd.factorize(all_data['Product_Info_2'])[0]
# all_data['Product_Info_2_char'] = pd.factorize(all_data['Product_Info_2_char'])[0]
# all_data['Product_Info_2_num'] = pd.factorize(all_data['Product_Info_2_num'])[0]

# all_data['BMI_Age'] = all_data['BMI'] * all_data['Ins_Age']

# med_keyword_columns = all_data.columns[all_data.columns.str.startswith('Medical_Keyword_')]
# all_data['Med_Keywords_Count'] = all_data[med_keyword_columns].sum(axis=1)

# print('Eliminate missing values')    
# all_data.fillna(missing_indicator, inplace=True)

# # fix the dtype on the label column
# all_data['Response'] = all_data['Response'].astype(int)

# # split train and test
# train = all_data[all_data['Response']>0].copy()
# test = all_data[all_data['Response']<1].copy()

# # convert data to xgb data structure
# xgtrain = xgb.DMatrix(train.drop(columns_to_drop, axis=1), train['Response'].values, 
#                         missing=missing_indicator)
# xgtest = xgb.DMatrix(test.drop(columns_to_drop, axis=1), label=test['Response'].values, 
#                         missing=missing_indicator)    

# # get the parameters for xgboost
# plst = get_params()
# print(plst)      

# # train model
# model = xgb.train(plst, xgtrain, xgb_num_rounds) 

# # get preds
# train_preds = model.predict(xgtrain, ntree_limit=model.best_iteration)
# print('Train score is:', eval_wrapper(train_preds, train['Response'])) 
# test_preds = model.predict(xgtest, ntree_limit=model.best_iteration)

# # train offsets 
# offsets = np.array([0.1, -1, -2, -1, -0.8, 0.02, 0.8, 1])
# offset_preds = np.vstack((train_preds, train_preds, train['Response'].values))
# offset_preds = apply_offsets(offset_preds, offsets)
# opt_order = [6,4,5,3]
# for j in opt_order:
#     train_offset = lambda x: -score_offset(offset_preds, x, j) * 100
#     offsets[j] = fmin_powell(train_offset, offsets[j], disp=False)

# print('Offset Train score is:', eval_wrapper(offset_preds[1], train['Response'])) 

# # apply offsets to test
# data = np.vstack((test_preds, test_preds, test['Response'].values))
# data = apply_offsets(data, offsets)

# final_test_preds = np.round(np.clip(data[1], 1, 8)).astype(int)

# preds_out = pd.DataFrame({"Id": test['Id'].values, "Response": final_test_preds})
# preds_out = preds_out.set_index('Id')
# preds_out.to_csv('xgb_offset_submission.csv')
# Out:
# Load the data using pandas
# Eliminate missing values
# [('colsample_bytree', 0.3), ('silent', 1), ('min_child_weight', 360), ('subsample', 0.85), ('eta', 0.05), ('objective', 'reg:linear'), ('max_depth', 7)]
# ('Train score is:', 0.6510593682006414)
# ('Offset Train score is:', 0.7028284528344464)

# %%
#Greedy add 1 by 1
scr = []
c = ["Product_Info_4", "Ins_Age", "Ht", "Wt", "BMI", "Employment_Info_1", "Employment_Info_4", "Employment_Info_6",
              "Insurance_History_5", "Family_Hist_2", "Family_Hist_3", "Family_Hist_4", "Family_Hist_5"]
for t in range(1):
    score={}
    for f in c:
        if f in scr:
            pass
        else:
            scr.append(f)
            scr.append('Response')
            xz=train[scr]
            xz = xz.dropna()
            y_t=xz['Response']
            x_t=xz.drop(['Response'],axis=1)
            log_model = linear_model.LogisticRegression(solver='lbfgs',multi_class='multinomial')
            #log_model.fit(pd.DataFrame(xz[scr]), pd.DataFrame(xz['Response']))
            log_model.fit(x_t,y_t)
            score[f]=log_model.score(x_t,y_t)
            #score.append([f,log_model.score(pd.DataFrame(xz[scr]),pd.DataFrame(xz['Response']))])
            scr.remove(f)
            scr.remove('Response')
    print score
    scr.append(max(score.iteritems(), key=operator.itemgetter(1))[0])
# Out:
# {'Family_Hist_3': 0.23579952267303103, 'Family_Hist_2': 0.41090317331163545, 'Family_Hist_5': 0.21001707455890722, 'Ins_Age': 0.33402940334450415, 'Insurance_History_5': 0.31140208915698103, 'BMI': 0.40464121520351626, 'Ht': 0.32764689041949446, 'Employment_Info_4': 0.33458803847762442, 'Wt': 0.38940065003957497, 'Employment_Info_1': 0.32813921363835452, 'Family_Hist_4': 0.38316292260616464, 'Employment_Info_6': 0.32614832979578379, 'Product_Info_4': 0.3282026237348647}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b047dfa2beed> in <module>()
#      17             log_model = linear_model.LogisticRegression(solver='lbfgs',multi_class='multinomial')
#      18             #log_model.fit(pd.DataFrame(xz[scr]), pd.DataFrame(xz['Response']))
# ---> 19             log_model.fit(x_t,y_t)
#      20             score[f]=log_model.score(x_t,y_t)
# ...

# %%
print scr
# Out:
# ['Family_Hist_2']

# %%
scr.append('Response')
xz=train[scr]
xz = xz.dropna()
y_t=xz['Response']
x_t=xz.drop(['Response'],axis=1)
log_model = linear_model.LogisticRegression(solver='lbfgs',multi_class='multinomial')
log_model.fit(x_t,y_t)
print log_model.score(x_t,y_t)
# Out:
# 0.41050167562

# %%
train.head()
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
# 3   7               1             D4              10        0.487179
# 4   8               1             D2              26        0.230769
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               1               1  0.641791  0.581818
# 1               2               3               1  0.059701  0.600000
# 2               2               3               1  0.029851  0.745455
# 3               2               3               1  0.164179  0.672727
# 4               2               3               1  0.417910  0.654545
#
#      ...     Medical_Keyword_40  Medical_Keyword_41  Medical_Keyword_42  \
# ...

# %%
forest = ExtraTreesClassifier(n_estimators=250, random_state=0)
c = ["Product_Info_4", "Ins_Age", "Ht", "Wt", "BMI","Family_Hist_2","Employment_Info_1","Response"]
#"Employment_Info_1", "Employment_Info_4", "Employment_Info_6","Insurance_History_5"
X=train[c]
X=X.dropna()
y=X['Response']
X=X.drop(['Response'],axis=1)
X.info()
forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
for f in range(X.shape[1]):
    print("%d. %s (%f)" % (f+1, c[indices[f]], importances[indices[f]]))
# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30721 entries, 1 to 59378
# Data columns (total 7 columns):
# Product_Info_4       30721 non-null float64
# Ins_Age              30721 non-null float64
# Ht                   30721 non-null float64
# Wt                   30721 non-null float64
# BMI                  30721 non-null float64
# Family_Hist_2        30721 non-null float64
# Employment_Info_1    30721 non-null float64
# dtypes: float64(7)
# memory usage: 1.9 MB
# Feature ranking:
# 1. BMI (0.195578)
# 2. Wt (0.163247)
# 3. Employment_Info_1 (0.158264)
# 4. Family_Hist_2 (0.149808)
# 5. Ins_Age (0.144628)
# 6. Ht (0.094656)
# 7. Product_Info_4 (0.093818)

# %%
#Fill by random generation
#x=pd.DataFrame(pd.value_counts(train['Family_Hist_2']))
plt.hist(train['Family_Hist_2'].dropna())
std= np.std(train['Family_Hist_2'].dropna())
mean= np.mean(train['Family_Hist_2'].dropna())
count_nan = train['Family_Hist_2'].isnull().sum()
rand_1 = np.random.normal(mean,std,count_nan)
train['Family_Hist_2'][np.isnan(train['Family_Hist_2'])]=rand_1
#train['Family_Hist_2'].hist()

# %%
#Fill by Response 
train['Employment_Info_1'][np.isnan(train['Employment_Info_1'])]=np.mean(train['Employment_Info_1'].dropna())
facet = sns.FacetGrid(train, hue="Response",aspect=4)
facet.map(sns.kdeplot,'Employment_Info_1',shade= True)
facet.set(xlim=(0, titanic_df['Employment_Info_1'].max()))
facet.add_legend()
plt.show()
#plt.hist(train.Employment_Info_4.dropna())
# Out:
# /Users/shashank/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-2a58b6d7a99b> in <module>()
#       1 #Fill by Response
#       2 train['Employment_Info_1'][np.isnan(train['Employment_Info_1'])]=np.mean(train['Employment_Info_1'].dropna())
# ----> 3 facet = sns.FacetGrid(train, hue="Response",aspect=4)
#       4 facet.map(sns.kdeplot,'Employment_Info_1',shade= True)
#       5 facet.set(xlim=(0, titanic_df['Employment_Info_1'].max()))
#
# NameError: name 'sns' is not defined
